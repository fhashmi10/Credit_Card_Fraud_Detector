# %% [markdown]
# ##### For classification problems

# %%
from collections import Counter
from matplotlib import pyplot
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/credit-card-default.csv')

X = df.drop(columns=['Class'], axis=1)
y = df['Class']

# %%
# summarize class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 23364, 1: 6636})

# %%
#### There is class imbalance

# %%
# scatter plot of examples by class label
X_arr=np.array(X)
for label, _ in counter.items():
	row_ix = np.where(y == label)[0]
	pyplot.scatter(X_arr[row_ix, 0], X_arr[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\fhash\anaconda3\envs\creditcardfraud\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\fhash\anaconda3\envs\creditcardfraud\lib\site-packages (from imbalanced-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\fhash\anaconda3\envs\creditcardfraud\lib\site-packages (from imbalanced-learn) (1.11.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\fhash\anaconda3\envs\creditcardfraud\lib\site-packages (from imbalanced-learn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\fhash\anaconda3\envs\creditcardfraud\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fhash\anaconda3\envs\creditcardfraud\lib\site-packages (from imbalanced-learn) (3.2.0)

# %%
from imblearn import over_sampling
# transform the dataset
oversample = over_sampling.SMOTE(random_state=0)
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
X_arr=np.array(X)
for label, _ in counter.items():
 row_ix = np.where(y == label)[0]
 pyplot.scatter(X_arr[row_ix, 0], X_arr[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({1: 23364, 0: 23364})
